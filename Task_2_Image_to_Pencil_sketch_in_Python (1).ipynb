# %% [markdown]
# Aditya Rameshwar Pachpille
#
# LGMVIP | Data Science
#
# Task 2:- Image to Pencil sketch in Python

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("aditya_.jpg.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1066x1066 at 0x7F860B133850>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=1066x1066 at 0x7F860B10C4D0>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=1066x1066 at 0x7F860B11A190>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=1066x1066 at 0x7F860B11A190>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=1066x1066 at 0x7F860B11ACD0>

# %% [markdown]
# # **Thank** ***You***
